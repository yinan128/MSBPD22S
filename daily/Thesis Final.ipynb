dGSAClimate = "buildings.xlsx"
theBuildingList = pd.read_excel(dGSAClimate)
theBuildingList['Climate Zone'] = theBuildingList['Climate Zone'].replace([7], '7')
CTClimateZoneUni = theBuildingList[theBuildingList['Function'] == 'CT']['Climate Zone'].unique().tolist()
CTOClimateZoneUni = theBuildingList[theBuildingList['Function'] == 'CT/O']['Climate Zone'].unique().tolist()
officeClimateZoneUni = theBuildingList[theBuildingList['Function'] == 'O']['Climate Zone'].unique().tolist()
for i in range(len(officeClimateZoneUni)):
    if officeClimateZoneUni[i] == 7:
        officeClimateZoneUni[i] = '7'
for i in range(len(CTOClimateZoneUni)):
    if CTOClimateZoneUni[i] == 7:
        CTOClimateZoneUni[i] = '7'

buildingArea = [0,50000, 100000, 300000, 600000,100000000000000000000000]
buildingAreaK = ['0', '50k', '100k', '300k', '600k', 'Over 600k']
buildingType = ['O','CT','C_T_O']
buildingTypeAndClimateZone = [officeClimateZoneUni, CTClimateZoneUni, CTOClimateZoneUni]

d292 = "afterQ290(Apr21).csv"
b290 = pd.read_csv(d292, parse_dates=['Timestamp'])
b290 = b290.set_index('Timestamp')
fullDayTimestamp = ['0:00',	'0:15',	'0:30',	'0:45',	'1:00',	'1:15',	'1:30',	'1:45',	'2:00',	'2:15',	'2:30',	'2:45',	'3:00',	'3:15',	'3:30',	'3:45',	'4:00',	'4:15',	'4:30',	'4:45',	'5:00',	'5:15',	'5:30',	'5:45',	'6:00',	'6:15',	'6:30',	'6:45',	'7:00',	'7:15',	'7:30',	'7:45',	'8:00',	'8:15',	'8:30',	'8:45',	'9:00',	'9:15',	'9:30',	'9:45',	'10:00',	'10:15',	'10:30',	'10:45',	'11:00',	'11:15',	'11:30',	'11:45',	'12:00',	'12:15',	'12:30',	'12:45',	'13:00',	'13:15',	'13:30',	'13:45',	'14:00',	'14:15',	'14:30',	'14:45',	'15:00',	'15:15',	'15:30',	'15:45',	'16:00',	'16:15',	'16:30',	'16:45',	'17:00',	'17:15',	'17:30',	'17:45',	'18:00',	'18:15',	'18:30',	'18:45',	'19:00',	'19:15',	'19:30',	'19:45',	'20:00',	'20:15',	'20:30',	'20:45',	'21:00',	'21:15',	'21:30',	'21:45',	'22:00',	'22:15',	'22:30',	'22:45',	'23:00',	'23:15',	'23:30',	'23:45']
dMerged = 'merged.xlsx'
merged = pd.read_excel(dMerged)
allDaysConcerned = [allWeekdayNoHoliday]
allDaysConcernedD = [' Weekdays No Holidays']
allClimateZoneUnique.sort()

# %%
#### Daily electricity consumption goal
#Get Average, Median, and 25
cA44 = pd.DataFrame()
cA44['Timestamp'] = fullDayTimestamp
cA44 = cA44.set_index('Timestamp')


cA45 = pd.DataFrame()
cA45['Timestamp'] = fullDayTimestamp
cA45 = cA45.set_index('Timestamp')

cA46 = pd.DataFrame()
cA46['Timestamp'] = fullDayTimestamp
cA46 = cA46.set_index('Timestamp')

# for ob1 in ['Winter']:
for ob1 in ['Summer']:
# for ob1 in ['Summer','Spring|Autumn']:
    for ob2 in ['Weekday','Weekend']:
        dWow = "Everything at Every Time.csv"
        theMoreEvery = pd.read_csv(dWow)
        
#         theMoreEvery = theMoreEvery[theMoreEvery['Timestamp'].str.contains(onlyEleB)]
#         theMoreEvery = theMoreEvery[theMoreEvery['Timestamp'].str.contains(onlyGasB)]
        
        getTheRowsC = theMoreEvery[theMoreEvery['Timestamp'].str.contains(ob1)]
        getTheRowsCC = getTheRowsC[getTheRowsC['Timestamp'].str.contains(ob2)]
        getTheRowsCC = getTheRowsCC.set_index('Timestamp')
        getTheRowsCC[getTheRowsCC <= 0] = np.nan

        backupC = getTheRowsCC.T
        checkC = getTheRowsCC.T
        
        checkCMeanSum = checkC.mean(axis=1,skipna=True).sum()
#         checkCMedianSum = checkC.median(axis=1,skipna=True).sum() 
#         q375sum = checkC.quantile(0.75,axis=1).sum()
#         q125sum = checkC.quantile(0.25,axis=1).sum()

        for oknow in checkC.columns.tolist():
            #Ensure the strictest standard as along as there is more wasting electricity, it is removed
            if checkC[oknow].sum()>2*checkCMeanSum:
#             if checkC[oknow].sum()>2*checkCMedianSum:
#             if checkC[oknow].sum()>q375sum:
#             if checkC[oknow].sum()>q375sum or checkC[oknow].sum()<q125sum:
                backupC = backupC.drop(columns=[oknow])
                
            else:
                pass
        backupCC = backupC.T

        plt.figure(figsize=(50,9))
        bp = backupCC.boxplot(showmeans=True,return_type='dict')

        getMeans = [item.get_ydata()[0] for item in bp['means']]
        getMedians = [item.get_ydata()[0] for item in bp['medians']]
        getMins = [item.get_ydata()[0] for item in bp['caps']][::2]
        getMaxs = [item.get_ydata()[0] for item in bp['caps']]
        get25 = [min(item.get_ydata()) for item in bp['boxes']]
        get75 = [max(item.get_ydata()) for item in bp['boxes']]

        # Get Means, Medians, and 25 goals
        cA44[ob1 + ' ' + ob2] = getMeans
        cA45[ob1 + ' ' + ob2] = getMedians
        cA46[ob1 + ' ' + ob2] = get25 
        plt.close()

# %%
## cA44 Means
#For Spring, Summer, and Autumn
dWow = "Everything at Every Time.csv"
theMoreEvery = pd.read_csv(dWow)

#For Winter
# theMoreEvery = theMoreEvery[theMoreEvery['Timestamp'].str.contains(onlyEleB)]
# theMoreEvery = theMoreEvery[theMoreEvery['Timestamp'].str.contains(onlyGasB)]

theMoreEvery = theMoreEvery.set_index('Timestamp')
theMoreEvery = theMoreEvery.T

print(1)
allNoHighSaved = pd.DataFrame()
allNoHighSaved['Building ID'] = []
allNoHighSaved['Area'] = []
allNoHighSaved['Day'] = []
allNoHighSaved['Season'] = []
allNoHighSaved['First Night Time Save'] = []
allNoHighSaved['Second Night Time Save'] = []
allNoHighSaved['Full Night Time Save'] = []
allNoHighSaved['Day Time Save'] = []
allNoHighSaved['Combined Save'] = []
allNoHighSaved['Total Consumption'] = []

qwe = 1
for ob1 in ['Winter']:
# for ob1 in ['Summer','Spring|Autumn']:
    for ob2 in ['Weekday','Weekend']:
        getob1 = theMoreEvery.filter(regex=ob1)
        getob2 = getob1.filter(regex=ob2)
        getFinal = getob2
        getTitle = ob1 + ' ' + ob2
        
        getBuildingFirst = getFinal.columns.tolist()
        for i in getBuildingFirst:
            print(qwe)
            qwe+=1
            mm = i[11:19]
            
            buildingIndexList = merged.index[merged['code'] == mm].tolist()
            floorA = merged.loc[merged['code'] == mm]['area'].get(key = buildingIndexList[0])
            
            full1 = ['0:00',	'0:15',	'0:30',	'0:45',	'1:00',	'1:15',	'1:30',	'1:45',	'2:00',	'2:15',	'2:30',	'2:45',	'3:00',	'3:15',	'3:30',	'3:45',	'4:00',	'4:15',	'4:30',	'4:45',	'5:00',	'5:15',	'5:30',	'5:45',	'6:00']
            full2 = ['6:15',	'6:30',	'6:45',	'7:00',	'7:15',	'7:30',	'7:45','8:00',	'8:15',	'8:30',	'8:45',	'9:00',	'9:15',	'9:30',	'9:45',	'10:00',	'10:15',	'10:30',	'10:45',	'11:00',	'11:15',	'11:30',	'11:45',	'12:00',	'12:15',	'12:30',	'12:45',	'13:00',	'13:15',	'13:30',	'13:45',	'14:00',	'14:15',	'14:30',	'14:45',	'15:00',	'15:15',	'15:30',	'15:45',	'16:00',	'16:15',	'16:30',	'16:45',	'17:00',	'17:15',	'17:30',	'17:45',	'18:00']
            full3= ['18:15',	'18:30',	'18:45',	'19:00',	'19:15',	'19:30',	'19:45',	'20:00',	'20:15',	'20:30',	'20:45',	'21:00',	'21:15',	'21:30',	'21:45',	'22:00',	'22:15',	'22:30',	'22:45',	'23:00',	'23:15',	'23:30',	'23:45']

            dayNoHighSaved = []
            nightNoHighSavedFirst = []
            nightNoHighSavedSecond = []
            dayNoHighLowSaved = []
            nightNoHighLowSavedFirst = [] 
            nightNoHighLowSavedSecond = []
            ########cA44 Mean Goal Saving
            for idkc2 in full2:
                curSaved = (getFinal[i].loc[idkc2]- cA44[getTitle].loc[idkc2])*floorA
                if curSaved < 0:
                    dayNoHighSaved.append(0)
                else:
                    dayNoHighSaved.append(curSaved)

            for idkc1 in full1:
                curSaved = (getFinal[i].loc[idkc1]- cA44[getTitle].loc[idkc1])*floorA
                if curSaved < 0:
                    nightNoHighSavedFirst.append(0)
                else:
                    nightNoHighSavedFirst.append(curSaved) 

            for idkc3 in full3:
                curSaved = (getFinal[i].loc[idkc3]- cA44[getTitle].loc[idkc3])*floorA
                if curSaved < 0:
                    nightNoHighSavedSecond.append(0)
                else:
                    nightNoHighSavedSecond.append(curSaved)         

            fullNoHighNight = np.nansum(nightNoHighSavedFirst)+np.nansum(nightNoHighSavedSecond)
            noHighSavingFull = fullNoHighNight+np.nansum(dayNoHighSaved) 

            fullNoHighLowNight = np.nansum(nightNoHighLowSavedFirst)+np.nansum(nightNoHighLowSavedSecond)
            noHighLowSavingFull = fullNoHighLowNight+np.nansum(dayNoHighLowSaved)
            
            allNoHighSaved = allNoHighSaved.append({'Day':i[33:39],'Season': i[20:23],'Building ID':mm, 'Area':floorA,'Day Time Save':np.nansum(dayNoHighSaved),'First Night Time Save':np.nansum(nightNoHighSavedFirst),'Second Night Time Save':np.nansum(nightNoHighSavedSecond),'Full Night Time Save': fullNoHighNight,'Combined Save':noHighSavingFull,'Total Consumption':b290[mm].sum()}, ignore_index=True)
            ########cA45 Median Goal Saving
            for idkc2 in full2:
                curSaved = (getFinal[i].loc[idkc2]- cA45[getTitle].loc[idkc2])*floorA
                if curSaved < 0:
                    dayNoHighSaved.append(0)
                else:
                    dayNoHighSaved.append(curSaved)

            for idkc1 in full1:
                curSaved = (getFinal[i].loc[idkc1]- cA45[getTitle].loc[idkc1])*floorA
                if curSaved < 0:
                    nightNoHighSavedFirst.append(0)
                else:
                    nightNoHighSavedFirst.append(curSaved) 

            for idkc3 in full3:
                curSaved = (getFinal[i].loc[idkc3]- cA45[getTitle].loc[idkc3])*floorA
                if curSaved < 0:
                    nightNoHighSavedSecond.append(0)
                else:
                    nightNoHighSavedSecond.append(curSaved)         

            fullNoHighNight = np.nansum(nightNoHighSavedFirst)+np.nansum(nightNoHighSavedSecond)
            noHighSavingFull = fullNoHighNight+np.nansum(dayNoHighSaved) 

            fullNoHighLowNight = np.nansum(nightNoHighLowSavedFirst)+np.nansum(nightNoHighLowSavedSecond)
            noHighLowSavingFull = fullNoHighLowNight+np.nansum(dayNoHighLowSaved)
            
            allNoHighSaved = allNoHighSaved.append({'Day':i[33:39],'Season': i[20:23],'Building ID':mm, 'Area':floorA,'Day Time Save':np.nansum(dayNoHighSaved),'First Night Time Save':np.nansum(nightNoHighSavedFirst),'Second Night Time Save':np.nansum(nightNoHighSavedSecond),'Full Night Time Save': fullNoHighNight,'Combined Save':noHighSavingFull,'Total Consumption':b290[mm].sum()}, ignore_index=True)
            ########cA46 25% Goal Saving
            for idkc2 in full2:
                curSaved = (getFinal[i].loc[idkc2]- cA46[getTitle].loc[idkc2])*floorA
                if curSaved < 0:
                    dayNoHighSaved.append(0)
                else:
                    dayNoHighSaved.append(curSaved)

            for idkc1 in full1:
                curSaved = (getFinal[i].loc[idkc1]- cA46[getTitle].loc[idkc1])*floorA
                if curSaved < 0:
                    nightNoHighSavedFirst.append(0)
                else:
                    nightNoHighSavedFirst.append(curSaved) 

            for idkc3 in full3:
                curSaved = (getFinal[i].loc[idkc3]- cA46[getTitle].loc[idkc3])*floorA
                if curSaved < 0:
                    nightNoHighSavedSecond.append(0)
                else:
                    nightNoHighSavedSecond.append(curSaved)         

            fullNoHighNight = np.nansum(nightNoHighSavedFirst)+np.nansum(nightNoHighSavedSecond)
            noHighSavingFull = fullNoHighNight+np.nansum(dayNoHighSaved) 

            fullNoHighLowNight = np.nansum(nightNoHighLowSavedFirst)+np.nansum(nightNoHighLowSavedSecond)
            noHighLowSavingFull = fullNoHighLowNight+np.nansum(dayNoHighLowSaved)
            
            allNoHighSaved = allNoHighSaved.append({'Day':i[33:39],'Season': i[20:23],'Building ID':mm, 'Area':floorA,'Day Time Save':np.nansum(dayNoHighSaved),'First Night Time Save':np.nansum(nightNoHighSavedFirst),'Second Night Time Save':np.nansum(nightNoHighSavedSecond),'Full Night Time Save': fullNoHighNight,'Combined Save':noHighSavingFull,'Total Consumption':b290[mm].sum()}, ignore_index=True)
print(datetime.datetime.now())

# %%
#### Startup/shutdown time
#get the new startup/shutdown saving
# Climate Zone is not explored, I do not want to change the code as doing so may crash it.
dNew = "the clocks.csv"
theNew = pd.read_csv(dNew)
qwe = 0
getStartOnly = pd.DataFrame()
getShutOnly = pd.DataFrame()

allClimateZone = []
for i in buildingTypeAndClimateZone:
    for j in i:
        allClimateZone.append(j) 
allClimateZoneUnique = []
for i in allClimateZone:
    if i in allClimateZoneUnique:
        pass
    else:
        allClimateZoneUnique.append(i)
allClimateZoneUnique.sort()
startShift = 0
shutShift = 0
# for theNeededWeekday in ['Friday', 'NoFri']:
for theNeededWeekday in ['Monday', 'NoMon']:
    print(qwe)
    qwe += 1
    
    gStart = theNew[(theNew['StartW'] == theNeededWeekday)]['Startup Time Ave'].tolist()
    gShut = theNew[(theNew['StartW'] == theNeededWeekday)]['Shutdown Time Ave'].tolist()
#     gStart = theNew[(theNew['ShutW'] == theNeededWeekday)]['Startup Time Ave'].tolist()
#     gShut = theNew[(theNew['ShutW'] == theNeededWeekday)]['Shutdown Time Ave'].tolist()
    
    startData = np.array(gStart)
    q3Start,q1Start = np.percentile(startData, [75 ,25])
    iqrStart = q3Start - q1Start
    higherLStart = q3Start + iqrStart*1.5
    lowerLStart = q1Start - iqrStart*1.5
    gStartNew = [i for i in gStart if lowerLStart <= i <= higherLStart]

    shutData = np.array(gShut)
    q3Shut,q1Shut = np.percentile(shutData, [75 ,25])
    iqrShut = q3Shut - q1Shut
    higherLShut = q3Shut + iqrShut*1.5
    lowerLShut = q1Shut - iqrShut*1.5
    gShutNew = [i for i in gShut if lowerLShut <= i <= higherLShut]

    for j in gStartNew:
        getStartOnly = getStartOnly.append({theNeededWeekday:j}, ignore_index=True)
    for k in gShutNew:  
        getShutOnly = getShutOnly.append({theNeededWeekday:k}, ignore_index=True)

    getStartOnly[theNeededWeekday] = getStartOnly[theNeededWeekday].shift(-startShift)
    getShutOnly[theNeededWeekday] = getShutOnly[theNeededWeekday].shift(-shutShift)
    
    startShift += len(gStartNew)
    shutShift += len(gShutNew)

# Separate Monday from Other days for startup
# Do not need to separate Shutdown

# %%
# get Average Startup Shutdown for each CZ (CZ is just a placeholder, for naming only)
# We only look at the national startup/shutdown goals
getAve = pd.DataFrame()
getAve['CZ'] = []
getAve['Startup'] = []
getAve['Shutdown'] = []

CZs = getStartOnly.columns.tolist()

for i in CZs:
    aveStart = getStartOnly[i].tolist()
    aveShut = getShutOnly[i].tolist()
    dictTCS1 = {'CZ':i,'Startup':np.nanmean(aveStart),'Shutdown':np.nanmean(aveShut)}
    getAve = getAve.append(dictTCS1, ignore_index = True)
#####################
#get median Startup Shutdown for each CZ but Istill use getAve
getAve = pd.DataFrame()
getAve['CZ'] = []
getAve['Startup'] = []
getAve['Shutdown'] = []

CZs = getStartOnly.columns.tolist()

for i in CZs:
    aveStart = getStartOnly[i].tolist()
    aveShut = getShutOnly[i].tolist()
    dictTCS1 = {'CZ':i,'Startup':np.nanmedian(aveStart),'Shutdown':np.nanmedian(aveShut)}
    getAve = getAve.append(dictTCS1, ignore_index = True)
##################
#75% Startup 25% shutdown
getAve = pd.DataFrame()
getAve['CZ'] = []
getAve['Startup'] = []
getAve['Shutdown'] = []
CZs = getStartOnly.columns.tolist()
for i in CZs:
    aveStart = getStartOnly[i].tolist()
    aveShut = getShutOnly[i].tolist()
    dictTCS1 = {'CZ':i,'Startup':np.nanpercentile(aveStart,75),'Shutdown':np.nanpercentile(aveShut,25)}
    getAve = getAve.append(dictTCS1, ignore_index = True)

# %%
dNew = "the clocks.csv"
theNew = pd.read_csv(dNew)

dClock = "the numbers.csv"
theClock = pd.read_csv(dClock)

totalSaved = pd.DataFrame()
totalSaved['Building ID'] = []
totalSaved['WDay'] = []
totalSaved['Date'] = []
totalSaved['Startup Saved'] = []
totalSaved['Shutdown Saved'] = []

allClimateZone = []
for i in buildingTypeAndClimateZone:
    for j in i:
        allClimateZone.append(j) 
allClimateZoneUnique = []
for i in allClimateZone:
    if i in allClimateZoneUnique:
        pass
    else:
        allClimateZoneUnique.append(i)
allClimateZoneUnique.sort()

# for theNeededWeekday in ['Friday', 'NoFri']:
for theNeededWeekday in ['Monday','NoMon']:
    getTheRows = theNew[theNew['StartW'].str.contains(theNeededWeekday)]
#     getTheRows = theNew[theNew['ShutW'].str.contains(theNeededWeekday)]

    getTheRowsC = theClock[theClock['StartW'].str.contains(theNeededWeekday)]
#     getTheRowsC = theClock[theClock['ShutW'].str.contains(theNeededWeekday)]
    
    getWhatIWant = getTheRows['Category'].tolist()

    currentStart = getAve[(getAve['CZ'] == theNeededWeekday)]['Startup'].sum()
    currentShut = getAve[(getAve['CZ'] == theNeededWeekday)]['Shutdown'].sum()
    
    if currentStart>6:
        currentStart = 6
    
    print(currentStart)
    print(currentShut)
    for i in getWhatIWant:

        theBuildingStart = getTheRows[(getTheRows['Category'] == i)]['Startup Time Ave'].sum()
        theBuildingShut = getTheRows[(getTheRows['Category'] == i)]['Shutdown Time Ave'].sum()

        theBuildingStartC = getTheRowsC[(getTheRowsC['Category'] == i)]['Startup Time Ave'].sum()
        theBuildingShutC = getTheRowsC[(getTheRowsC['Category'] == i)]['Shutdown Time Ave'].sum()

        startupShift = round((int(currentStart) - int(theBuildingStart))*60/15)*15
        shutdownShift = round((int(theBuildingShut) - int(currentShut))*60/15)*15

        if shutdownShift<=0 and startupShift<=0:
            dictTCS2 = {'WDay': theNeededWeekday,'Building ID':i[0:8],'Date':i[9:19],'Startup Saved':0,'Shutdown Saved':0}
            totalSaved = totalSaved.append(dictTCS2, ignore_index = True)
        elif startupShift<=0:

            getTheDataOrigin2 = b290[i[0:8]].loc[i[9:19]]
            getTheDataAfter2 = b290[i[0:8]].loc[i[9:19]]
            freq2 = 'm'
            getTheDataAfter2.index = getTheDataAfter2.index - pd.Timedelta(shutdownShift, unit=freq2) 
            strShut2 = i[9:19] +' 18:00:00'
            firstPart2 = getTheDataOrigin2.loc[strShut2:i[9:19] + ' ' + theBuildingShutC]
            secondPart2= getTheDataAfter2.loc[strShut2:i[9:19] + ' ' + theBuildingShutC]
            savedEnShutdown2 = (firstPart2-secondPart2).sum()

            if savedEnShutdown2 <0:
                savedEnShutdown2 = 0
            elif math.isnan(savedEnShutdown2):
                savedEnShutdown2 = 0

            dictTCS2 = {'WDay': theNeededWeekday,'Building ID':i[0:8],'Date':i[9:19],'Startup Saved':0,'Shutdown Saved':savedEnShutdown2}
            totalSaved = totalSaved.append(dictTCS2, ignore_index = True)

        elif shutdownShift<=0:

            getTheDataOrigin1 = b290[i[0:8]].loc[i[9:19]]
            getTheDataAfter1 = b290[i[0:8]].loc[i[9:19]]
            freq1 = 'm'
            getTheDataAfter1.index = getTheDataAfter1.index + pd.Timedelta(startupShift, unit=freq1) 
            peakStart1 = i[9:19] +' 06:00:00'
            firstPart1 = getTheDataOrigin1.loc[i[9:19] + ' ' + theBuildingStartC:peakStart1]
            secondPart1 = getTheDataAfter1.loc[i[9:19] + ' ' + theBuildingStartC:peakStart1]
            savedEnStartup1 = (firstPart1-secondPart1).sum()

            if savedEnStartup1 <0:
                savedEnStartup1 = 0
            elif math.isnan(savedEnStartup1):
                savedEnStartup1 = 0
            dictTCS1 = {'WDay': theNeededWeekday,'Building ID':i[0:8],'Date':i[9:19],'Startup Saved':savedEnStartup1,'Shutdown Saved':0}
            totalSaved = totalSaved.append(dictTCS1, ignore_index = True)
        else:
            getTheDataOrigin1 = b290[i[0:8]].loc[i[9:19]]
            getTheDataAfter1 = b290[i[0:8]].loc[i[9:19]]
            freq1 = 'm'
            getTheDataAfter1.index = getTheDataAfter1.index + pd.Timedelta(startupShift, unit=freq1) 
            peakStart1 = i[9:19] +' 06:00:00'
            firstPart1 = getTheDataOrigin1.loc[i[9:19] + ' ' + theBuildingStartC:peakStart1]
            secondPart1 = getTheDataAfter1.loc[i[9:19] + ' ' + theBuildingStartC:peakStart1]
            savedEnStartup1 = (firstPart1-secondPart1).sum()

            if savedEnStartup1 <0:
                savedEnStartup1 = 0
            elif math.isnan(savedEnStartup1):
                savedEnStartup1 = 0

            getTheDataOrigin2 = b290[i[0:8]].loc[i[9:19]]
            getTheDataAfter2 = b290[i[0:8]].loc[i[9:19]]
            freq2 = 'm'
            getTheDataAfter2.index = getTheDataAfter2.index - pd.Timedelta(shutdownShift, unit=freq2) 
allSunNoHoliday = ['2018-1-7',	'2018-1-14',	'2018-1-21',	'2018-1-28',	'2018-2-4',	'2018-2-11',	'2018-2-18',	'2018-2-25',	'2018-3-4',	'2018-3-11',	'2018-3-18',	'2018-3-25',	'2018-4-1',	'2018-4-8',	'2018-4-15',	'2018-4-22',	'2018-4-29',	'2018-5-6',	'2018-5-13',	'2018-5-20',	'2018-5-27',	'2018-6-3',	'2018-6-10',	'2018-6-17',	'2018-6-24',	'2018-7-1',	'2018-7-8',	'2018-7-15',	'2018-7-22',	'2018-7-29',	'2018-8-5',	'2018-8-12',	'2018-8-19',	'2018-8-26',	'2018-9-2',	'2018-9-9',	'2018-9-16',	'2018-9-23',	'2018-9-30',	'2018-10-7',	'2018-10-14',	'2018-10-21',	'2018-10-28',	'2018-11-4',	'2018-11-11',	'2018-11-18',	'2018-11-25',	'2018-12-2',	'2018-12-9']

# (1) Get weekdays averages (full 236 or for each weekday)
# for buildings in each catgory and plot average (black thick dash)
dGSAClimate = "buildings.xlsx"
theBuildingList = pd.read_excel(dGSAClimate)
theBuildingList['Climate Zone'] = theBuildingList['Climate Zone'].replace([7], '7')
CTClimateZoneUni = theBuildingList[theBuildingList['Function'] == 'CT']['Climate Zone'].unique().tolist()
CTOClimateZoneUni = theBuildingList[theBuildingList['Function'] == 'CT/O']['Climate Zone'].unique().tolist()
officeClimateZoneUni = theBuildingList[theBuildingList['Function'] == 'O']['Climate Zone'].unique().tolist()
for i in range(len(officeClimateZoneUni)):
    if officeClimateZoneUni[i] == 7:
        officeClimateZoneUni[i] = '7'
for i in range(len(CTOClimateZoneUni)):
    if CTOClimateZoneUni[i] == 7:
        CTOClimateZoneUni[i] = '7'
    
buildingArea = [0,50000, 100000, 300000, 600000,100000000000000000000000]
buildingAreaK = ['0', '50k', '100k', '300k', '600k', 'Over 600k']
buildingType = ['O','CT','CT/O']
buildingTypeAndClimateZone = [officeClimateZoneUni, CTClimateZoneUni, CTOClimateZoneUni]
d292 = "afterQ290(Apr21).csv"
b290 = pd.read_csv(d292, parse_dates=['Timestamp'])
b290 = b290.set_index('Timestamp')
fullDayTimestamp = ['0:00',	'0:15',	'0:30',	'0:45',	'1:00',	'1:15',	'1:30',	'1:45',	'2:00',	'2:15',	'2:30',	'2:45',	'3:00',	'3:15',	'3:30',	'3:45',	'4:00',	'4:15',	'4:30',	'4:45',	'5:00',	'5:15',	'5:30',	'5:45',	'6:00',	'6:15',	'6:30',	'6:45',	'7:00',	'7:15',	'7:30',	'7:45',	'8:00',	'8:15',	'8:30',	'8:45',	'9:00',	'9:15',	'9:30',	'9:45',	'10:00',	'10:15',	'10:30',	'10:45',	'11:00',	'11:15',	'11:30',	'11:45',	'12:00',	'12:15',	'12:30',	'12:45',	'13:00',	'13:15',	'13:30',	'13:45',	'14:00',	'14:15',	'14:30',	'14:45',	'15:00',	'15:15',	'15:30',	'15:45',	'16:00',	'16:15',	'16:30',	'16:45',	'17:00',	'17:15',	'17:30',	'17:45',	'18:00',	'18:15',	'18:30',	'18:45',	'19:00',	'19:15',	'19:30',	'19:45',	'20:00',	'20:15',	'20:30',	'20:45',	'21:00',	'21:15',	'21:30',	'21:45',	'22:00',	'22:15',	'22:30',	'22:45',	'23:00',	'23:15',	'23:30',	'23:45']
allHolidays = ['2018-1-1', '2018-1-15', '2018-2-19','2018-5-28','2018-7-4','2018-11-12','2018-11-22']
holidaysNames = ['New Years Day (Mon)', 'Martin Luther King Jr. Day (Mon)', 'Washingtons Birthday (Mon)', 'Memorial Day (Mon)', 'Independence Day (Wed)', 'Veterans Day (Observed) (Mon)', 'Thanksgiving (Thu)']

holiBuildings = theBuildingList['Building ID'].tolist()
holiBuildingFunctions = theBuildingList['Function'].tolist()
holiBuildingClimateZone = theBuildingList['Climate Zone'].tolist()
holiBuildingArea = theBuildingList['Area'].tolist()
holiBuildingGSA = theBuildingList['Regions'].tolist()

holiBuildings = b290.columns.tolist()
# holiBuildings.remove('MD0325ZZ')

qwe = 1
for i,j in zip(allHolidays, holidaysNames):
    for k,l,m,n,o in zip(holiBuildings,holiBuildingFunctions,holiBuildingClimateZone,holiBuildingArea,holiBuildingGSA):
        timeOver = []
        PB = []
        if i == '2018-1-1' or i =='2018-1-15' or i =='2018-2-19':
            aveOnhour = []
            for p in allWinterMondayNoHoliday: 
                peakLoad = b290[k].loc[p].quantile(0.95)
                theLittleQ = b290[k].loc[p].quantile(0.05)
                onHour = theLittleQ + 0.25*(peakLoad-theLittleQ)
                aveOnhour.append(onHour)
            
            meanOnHour = np.nanmean(aveOnhour)
            if len(b290[k].loc[i])==0:
                timeOver.append(99)
                PB.append(99)
            else:
                holiPeak = b290[k].loc[i].quantile(0.95)    
                holibase = b290[k].loc[i].quantile(0.15)  

                holiPeriod = b290[k].loc[i] > meanOnHour
                holiPeriod = b290[k].loc[i][holiPeriod]
                if len(holiPeriod)!=0:
                    timeOver.append(len(holiPeriod)*15)
                    PB.append(holiPeak/holibase)
                else:
                    timeOver.append(0)
                    PB.append(holiPeak/holibase)
  
        elif i == '2018-5-28':
            aveOnhour = []
            for p in allSpringMondayNoHoliday: 
                peakLoad = b290[k].loc[p].quantile(0.95)
                theLittleQ = b290[k].loc[p].quantile(0.05)
                onHour = theLittleQ + 0.25*(peakLoad-theLittleQ)
                aveOnhour.append(onHour)
                
            meanOnHour = np.nanmean(aveOnhour)    
            if len(b290[k].loc[i])==0:
                timeOver.append(99)
                PB.append(99)
            else:
                holiPeak = b290[k].loc[i].quantile(0.95)    
                holibase = b290[k].loc[i].quantile(0.15)  

                holiPeriod = b290[k].loc[i] > meanOnHour
                holiPeriod = b290[k].loc[i][holiPeriod]
                if len(holiPeriod)!=0:
                    timeOver.append(len(holiPeriod)*15)
                    PB.append(holiPeak/holibase)
                else:
                    timeOver.append(0)
                    PB.append(holiPeak/holibase)
           
        elif i == '2018-7-4':
            aveOnhour = []
            for p in allSummerWednesdayNoHoliday: 
                peakLoad = b290[k].loc[p].quantile(0.95)
                theLittleQ = b290[k].loc[p].quantile(0.05)
                onHour = theLittleQ + 0.25*(peakLoad-theLittleQ)
                aveOnhour.append(onHour)
                
            meanOnHour = np.nanmean(aveOnhour)    
            if len(b290[k].loc[i])==0:
                timeOver.append(99)
                PB.append(99)
            else:
                holiPeak = b290[k].loc[i].quantile(0.95)    
                holibase = b290[k].loc[i].quantile(0.15)  

                holiPeriod = b290[k].loc[i] > meanOnHour
                holiPeriod = b290[k].loc[i][holiPeriod]
                if len(holiPeriod)!=0:
                    timeOver.append(len(holiPeriod)*15)
                    PB.append(holiPeak/holibase)
                else:
                    timeOver.append(0)
                    PB.append(holiPeak/holibase)
            
        elif i == '2018-11-12':
            aveOnhour = []
            for p in allAutumnMondayNoHoliday: 
                peakLoad = b290[k].loc[p].quantile(0.95)
                theLittleQ = b290[k].loc[p].quantile(0.05)
                onHour = theLittleQ + 0.25*(peakLoad-theLittleQ)
                aveOnhour.append(onHour)
                
            meanOnHour = np.nanmean(aveOnhour)    
            if len(b290[k].loc[i])==0:
                timeOver.append(99)
                PB.append(99)
            else:
                holiPeak = b290[k].loc[i].quantile(0.95)    
                holibase = b290[k].loc[i].quantile(0.15)  

                holiPeriod = b290[k].loc[i] > meanOnHour
                holiPeriod = b290[k].loc[i][holiPeriod]
                if len(holiPeriod)!=0:
                    timeOver.append(len(holiPeriod)*15)
                    PB.append(holiPeak/holibase)
                else:
                    timeOver.append(0)
                    PB.append(holiPeak/holibase)
    
        elif i == '2018-11-22':
            aveOnhour = []
            for p in allAutumnThursdayNoHoliday: 
                peakLoad = b290[k].loc[p].quantile(0.95)
                theLittleQ = b290[k].loc[p].quantile(0.05)
                onHour = theLittleQ + 0.25*(peakLoad-theLittleQ)
                aveOnhour.append(onHour)
                
            meanOnHour = np.nanmean(aveOnhour)    
            if len(b290[k].loc[i])==0:
                timeOver.append(99)
                PB.append(99)
            else:
                holiPeak = b290[k].loc[i].quantile(0.95)    
                holibase = b290[k].loc[i].quantile(0.15)  

                holiPeriod = b290[k].loc[i] > meanOnHour
                holiPeriod = b290[k].loc[i][holiPeriod]
                if len(holiPeriod)!=0:
                    timeOver.append(len(holiPeriod)*15)
                    PB.append(holiPeak/holibase)
                else:
                    timeOver.append(0)
                    PB.append(holiPeak/holibase)
        
        
        holidayEnergy = holidayEnergy.append({'Building ID':k, 'Time Over On Hour':timeOver[0], 'Peak-base Ratio':PB[0],'All Holidays':i,'Holiday Names':j}, ignore_index=True)
        print(qwe)
        qwe+=1
    
# holidayEnergy.to_excel('Holiday.xlsx',index=False)

# %%
dDetect = "Holiday Detection.xlsx"
theDetect = pd.read_excel(dDetect)


holiBuildings = theDetect['Building ID'].tolist()
allHolidays = theDetect['All Holidays'].tolist()
holidaysNames = theDetect['Holiday Names'].tolist()
holiOnHour = theDetect['On Hour'].tolist()


qwe = 1
for i,j,k,l in zip(holiBuildings, allHolidays, holidaysNames, holiOnHour):
    if j == '2018-11-22':
        pass
    else:
        if j =='2018-1-1' or j == '2018-1-15' or j == '2018-2-19':
            daysConcerned = allWinterMondayNoHoliday
        elif j == '2018-5-28':
            daysConcerned = allSpringMondayNoHoliday
        elif j == '2018-7-4':
            daysConcerned = allSummerWednesdayNoHoliday 
        elif j == '2018-11-12':
            daysConcerned = allAutumnMondayNoHoliday

        print(j)
        print(daysConcerned)
        aveBuildingCon = pd.DataFrame()
        aveBuildingCon['Timestamp'] = fullDayTimestamp
        aveBuildingCon = aveBuildingCon.set_index('Timestamp')
        averageFull = [] 

        currentHolidayConsumption = b290[i].loc[j].sum()
        if currentHolidayConsumption == 0:
            currentHolidayConsumption = np.nan
        currentWeekdayConsumption = None
        energySavingUpper = None
        baseLoadFull = None
        energySavingLower = None

        for nn in fullDayTimestamp:
            getMinuteData = []
            for oo in daysConcerned: 
                constructedTime = oo + ' ' + nn
                getData = b290.loc[constructedTime].at[i]
                getMinuteData.append(getData)
            averageFull.append(np.nanmean(getMinuteData))
        aveBuildingCon[k] = averageFull

        holidayConsumption = b290[i].loc[j].dropna()
        holidayConsumption = holidayConsumption.loc[(holidayConsumption != 0)]
        q3 = holidayConsumption.quantile(0.75)
        q1 = holidayConsumption.quantile(0.25)
        interQ = q3 - q1
        rangeL = q1 - interQ * 1.5
        rangeH = q3 + interQ * 1.5
        d2 = holidayConsumption.between(rangeL, rangeH,inclusive = True)
        holidayConsumption = holidayConsumption[d2]
        currentHolidayConsumption = holidayConsumption.sum()

        holidayIndex = holidayConsumption.index.tolist()

        baseload =  holidayConsumption.quantile(0.15)
        if baseload == 0:
            baseload = aveBuildingCon.quantile(0.15)[0]
            if baseload == 0:
                baseload = np.nan
            elif math.isnan(baseload):
                baseload = np.nan
        elif math.isnan(baseload):
            baseload = aveBuildingCon.quantile(0.15)[0]
            if baseload == 0:
                baseload = np.nan
            elif math.isnan(baseload):
                baseload = np.nan


        baseLoadFull = baseload*len(holidayIndex)

        trueW = []
        for jj in holidayIndex:
            trueW.append(aveBuildingCon.loc[str(jj)[11:16]][0])
        currentWeekdayConsumption=np.nansum(trueW)
        if currentWeekdayConsumption == 0:
            currentWeekdayConsumption = np.nan

        totalSaving = []
        for ii in holidayIndex:
            oneTimeSaving = aveBuildingCon.loc[str(ii)[11:16]][0]-holidayConsumption.loc[ii]
            totalSaving.append(oneTimeSaving)
        energySavingUpper = np.nansum(totalSaving) 
        if energySavingUpper<0:
            energySavingUpper = 0

        baseLoadFull = baseload*len(holidayIndex)
        totalSaving = []
        energySavingLower =  currentHolidayConsumption - baseLoadFull

        if l == 1:
            dictL = {'Building ID': i, 'Holiday Names':k,'Date':j,'Energy use on Holiday (kWh)':currentHolidayConsumption,'Seasonal Daily Average Consumption (kWh)':currentWeekdayConsumption,'If Baseload (kWh)':baseLoadFull,'Current Energy Saving (kWh)':energySavingUpper,'More Energy Saving (kWh)':0}
            holidayEnergy = holidayEnergy.append(dictL, ignore_index = True)
        elif l == 0:
            dictL = {'Building ID': i, 'Holiday Names':k,'Date':j,'Energy use on Holiday (kWh)':currentHolidayConsumption,'Seasonal Daily Average Consumption (kWh)':currentWeekdayConsumption,'If Baseload (kWh)':baseLoadFull,'Current Energy Saving (kWh)':0,'More Energy Saving (kWh)':energySavingLower}
            holidayEnergy = holidayEnergy.append(dictL, ignore_index = True)


        print(qwe)
        qwe+=1
holidayEnergy.to_excel('Apr4 no 2018-11-22.xlsx')
